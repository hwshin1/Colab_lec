# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
titanic = sns.load_dataset('titanic')

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %% [markdown]
# # Titanic 정보
# ```
# #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# ```
# 대부분 891개지만 age를 보면 714개만 있다 이건 NaN 값이 있다는 것

# %%
titanic.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
df = titanic.loc[:, ['age', 'fare']]

# %%
df
# Out:
#       age     fare
# 0    22.0   7.2500
# 1    38.0  71.2833
# 2    26.0   7.9250
# 3    35.0  53.1000
# 4    35.0   8.0500
# ..    ...      ...
# 886  27.0  13.0000
# 887  19.0  30.0000
# 888   NaN  23.4500
# 889  26.0  30.0000
# 890  32.0   7.7500
#
# [891 rows x 2 columns]

# %%
df.head()
# Out:
#     age     fare
# 0  22.0   7.2500
# 1  38.0  71.2833
# 2  26.0   7.9250
# 3  35.0  53.1000
# 4  35.0   8.0500

# %%
df.tail(10)
# Out:
#       age     fare
# 881  33.0   7.8958
# 882  22.0  10.5167
# 883  28.0  10.5000
# 884  25.0   7.0500
# 885  39.0  29.1250
# 886  27.0  13.0000
# 887  19.0  30.0000
# 888   NaN  23.4500
# 889  26.0  30.0000
# 890  32.0   7.7500

# %%
addi = df + 10

# %%
addi
# Out:
#       age     fare
# 0    32.0  17.2500
# 1    48.0  81.2833
# 2    36.0  17.9250
# 3    45.0  63.1000
# 4    45.0  18.0500
# ..    ...      ...
# 886  37.0  23.0000
# 887  29.0  40.0000
# 888   NaN  33.4500
# 889  36.0  40.0000
# 890  42.0  17.7500
#
# [891 rows x 2 columns]

# %%
subt = addi - df

# %%
subt
# Out:
#       age  fare
# 0    10.0  10.0
# 1    10.0  10.0
# 2    10.0  10.0
# 3    10.0  10.0
# 4    10.0  10.0
# ..    ...   ...
# 886  10.0  10.0
# 887  10.0  10.0
# 888   NaN  10.0
# 889  10.0  10.0
# 890  10.0  10.0
#
# [891 rows x 2 columns]

# %%
sample1 = addi.tail()

# %%
sample1
# Out:
#       age   fare
# 886  37.0  23.00
# 887  29.0  40.00
# 888   NaN  33.45
# 889  36.0  40.00
# 890  42.0  17.75

# %%
# sample2 = subt.tail().fillna(0, 0)

# %%
# sample1.div(sample2, fill_value=0).fillna(0, 0)

# %%
df = df.iloc[:9]

# %%
df
# Out:
#     age     fare
# 0  22.0   7.2500
# 1  38.0  71.2833
# 2  26.0   7.9250
# 3  35.0  53.1000
# 4  35.0   8.0500
# 5   NaN   8.4583
# 6  54.0  51.8625
# 7   2.0  21.0750
# 8  27.0  11.1333

# %%
df['age']<20
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6    False
# 7     True
# 8    False
# Name: age, dtype: bool

# %%
df[df['age']<20]
# Out:
#    age    fare
# 7  2.0  21.075

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   age     8 non-null      float64
#  1   fare    9 non-null      float64
# dtypes: float64(2)
# memory usage: 276.0 bytes

# %%
df.reset_index()
# Out:
#    index   age     fare
# 0      0  22.0   7.2500
# 1      1  38.0  71.2833
# 2      2  26.0   7.9250
# 3      3  35.0  53.1000
# 4      4  35.0   8.0500
# 5      5   NaN   8.4583
# 6      6  54.0  51.8625
# 7      7   2.0  21.0750
# 8      8  27.0  11.1333

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   age     8 non-null      float64
#  1   fare    9 non-null      float64
# dtypes: float64(2)
# memory usage: 276.0 bytes

# %%
titanic.loc[0:9, ['age', 'fare']]
# Out:
#     age     fare
# 0  22.0   7.2500
# 1  38.0  71.2833
# 2  26.0   7.9250
# 3  35.0  53.1000
# 4  35.0   8.0500
# 5   NaN   8.4583
# 6  54.0  51.8625
# 7   2.0  21.0750
# 8  27.0  11.1333
# 9  14.0  30.0708

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df.loc[df['age']<20]
# Out:
#    age    fare
# 7  2.0  21.075

# %% [markdown]
# titanic 자료에서, 10에서 19세 승객 자료만 추출하기

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
titanic['age']
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: age, Length: 891, dtype: float64

# %%
titanic.loc[(titanic['age']>=10) & (titanic['age']<20)]
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked   class  \
# 9           1       2  female  14.0      1      0   30.0708        C  Second
# 14          0       3  female  14.0      0      0    7.8542        S   Third
# 22          1       3  female  15.0      0      0    8.0292        Q   Third
# 27          0       1    male  19.0      3      2  263.0000        S   First
# 38          0       3  female  18.0      2      0   18.0000        S   Third
# ..        ...     ...     ...   ...    ...    ...       ...      ...     ...
# 853         1       1  female  16.0      0      1   39.4000        S   First
# 855         1       3  female  18.0      0      1    9.3500        S   Third
# 875         1       3  female  15.0      0      0    7.2250        C   Third
# 877         0       3    male  19.0      0      0    7.8958        S   Third
# 887         1       1  female  19.0      0      0   30.0000        S   First
#
# ...

# %%
df_19
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 7           0       3    male   2.0      3      1  21.0750        S   Third
# 9           1       2  female  14.0      1      0  30.0708        C  Second
# 10          1       3  female   4.0      1      1  16.7000        S   Third
# 14          0       3  female  14.0      0      0   7.8542        S   Third
# 16          0       3    male   2.0      4      1  29.1250        Q   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 855         1       3  female  18.0      0      1   9.3500        S   Third
# 869         1       3    male   4.0      1      1  11.1333        S   Third
# 875         1       3  female  15.0      0      0   7.2250        C   Third
# 877         0       3    male  19.0      0      0   7.8958        S   Third
# 887         1       1  female  19.0      0      0  30.0000        S   First
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
# 강사님 버전
mask = (titanic['age']>=10) & (titanic['age']<20)
titanic.loc[mask].head()
# Out:
#     survived  pclass     sex   age  sibsp  parch      fare embarked   class  \
# 9          1       2  female  14.0      1      0   30.0708        C  Second
# 14         0       3  female  14.0      0      0    7.8542        S   Third
# 22         1       3  female  15.0      0      0    8.0292        Q   Third
# 27         0       1    male  19.0      3      2  263.0000        S   First
# 38         0       3  female  18.0      2      0   18.0000        S   Third
#
#       who  adult_male deck  embark_town alive  alone
# 9   child       False  NaN    Cherbourg   yes  False
# 14  child       False  NaN  Southampton    no   True
# 22  child       False  NaN   Queenstown   yes   True
# 27    man        True    C  Southampton    no  False
# 38  woman       False  NaN  Southampton    no  False

# %% [markdown]
# titanic 자료에서, 9세미만, 여성 승객자료만 추출

# %%
titanic_female_n = (titanic['sex']=='female') & (titanic['age'] < 9)

# %%
titanic_female_n
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Length: 891, dtype: bool

# %%
titanic.loc[titanic_female_n]
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked   class  \
# 10          1       3  female  4.00      1      1   16.7000        S   Third
# 24          0       3  female  8.00      3      1   21.0750        S   Third
# 43          1       2  female  3.00      1      2   41.5792        C  Second
# 58          1       2  female  5.00      1      2   27.7500        S  Second
# 119         0       3  female  2.00      4      2   31.2750        S   Third
# 172         1       3  female  1.00      1      1   11.1333        S   Third
# 184         1       3  female  4.00      0      2   22.0250        S   Third
# 205         0       3  female  2.00      0      1   10.4625        S   Third
# 233         1       3  female  5.00      4      2   31.3875        S   Third
# 237         1       2  female  8.00      0      2   26.2500        S  Second
# 297         0       1  female  2.00      1      2  151.5500        S   First
# ...

# %%
titanic_n = titanic.loc[titanic['age'] < 9]

# %%
titanic_n.loc[titanic_n['sex'] == 'female']
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked   class  \
# 10          1       3  female  4.00      1      1   16.7000        S   Third
# 24          0       3  female  8.00      3      1   21.0750        S   Third
# 43          1       2  female  3.00      1      2   41.5792        C  Second
# 58          1       2  female  5.00      1      2   27.7500        S  Second
# 119         0       3  female  2.00      4      2   31.2750        S   Third
# 172         1       3  female  1.00      1      1   11.1333        S   Third
# 184         1       3  female  4.00      0      2   22.0250        S   Third
# 205         0       3  female  2.00      0      1   10.4625        S   Third
# 233         1       3  female  5.00      4      2   31.3875        S   Third
# 237         1       2  female  8.00      0      2   26.2500        S  Second
# 297         0       1  female  2.00      1      2  151.5500        S   First
# ...

# %%
df.query('age < 20')
# Out:
#    age    fare
# 7  2.0  21.075

# %%
df.query('age >= 20 and fare < 15')
# Out:
#     age     fare
# 0  22.0   7.2500
# 2  26.0   7.9250
# 4  35.0   8.0500
# 8  27.0  11.1333

# %%
df.query('age not in [21, 22, 23, 24]')
# Out:
#     age     fare
# 1  38.0  71.2833
# 2  26.0   7.9250
# 3  35.0  53.1000
# 4  35.0   8.0500
# 5   NaN   8.4583
# 6  54.0  51.8625
# 7   2.0  21.0750
# 8  27.0  11.1333

# %%
def max_user(x, y):
    return max(x, y)

# %%
max_user(1 ,4)
# Out:
# 4

# %%
max(1, 4)
# Out:
# 4

# %%
df.query('age > @max_user(1, 10)')
# Out:
#     age     fare
# 0  22.0   7.2500
# 1  38.0  71.2833
# 2  26.0   7.9250
# 3  35.0  53.1000
# 4  35.0   8.0500
# 6  54.0  51.8625
# 8  27.0  11.1333

# %%
df.query('index > 3')
# Out:
#     age     fare
# 4  35.0   8.0500
# 5   NaN   8.4583
# 6  54.0  51.8625
# 7   2.0  21.0750
# 8  27.0  11.1333

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
titanic['class'].str.match('c') # 시리즈인데 문자열 기능을 붙이려고 str을 붙인다
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Name: class, Length: 891, dtype: bool

# %%
mask1 = titanic['embark_town'] == 'Southampton'
mask2 = titanic['embark_town'].str.match('Queenstown')
df_bool = titanic.loc[mask1 | mask2, :]
df_bool.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
# 5         0       3    male   NaN      0      0   8.4583        Q  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True
# 5    man        True  NaN   Queenstown    no   True

# %%
isin_filter = titanic['embark_town'].isin(['Queenstown', 'Southampton'])
df_isin = titanic.loc[isin_filter]

# %%
df_isin.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
# 5         0       3    male   NaN      0      0   8.4583        Q  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True
# 5    man        True  NaN   Queenstown    no   True

# %%
ser = pd.Series(['Apple_사과', 'Banana_바나나', 'Cherry_체리', np.nan],
                index=['First', ' Second', ' Third', 'Fourth'])

# %%
ser
# Out:
# First        Apple_사과
#  Second    Banana_바나나
#  Third      Cherry_체리
# Fourth            NaN
# dtype: object

# %%
ser.str.len()
# Out:
# First       8.0
#  Second    10.0
#  Third      9.0
# Fourth      NaN
# dtype: float64

# %%
ser.str.split('_', expand=True) # expand 하면 데이터 프레임으로 만들어진다?
# Out:
#               0    1
# First     Apple   사과
#  Second  Banana  바나나
#  Third   Cherry   체리
# Fourth      NaN  NaN

# %%
ser.index
# Out:
# Index(['First', ' Second', ' Third', 'Fourth'], dtype='object')

# %%
ser.index.str.strip()
# Out:
# Index(['First', 'Second', 'Third', 'Fourth'], dtype='object')

# %%
ser.index.str.replace('T', 'S') # T를 S로
# Out:
# Index(['First', ' Second', ' Shird', 'Fourth'], dtype='object')

# %%
# %%writefile ex1.csv
# a,b,c,d,message
# 1,2,3,4,hello
# 5,6,7,8,world
# 9,10,11,12,foo
# Out:
# Overwriting ex1.csv

# %%
df = pd.read_csv('ex1.csv')

# %%
df
# Out:
#    a   b   c   d message
# 0  1   2   3   4   hello
# 1  5   6   7   8   world
# 2  9  10  11  12     foo

# %%
pd.read_table('ex1.csv', sep=',') # sep 구분자
# Out:
#    a   b   c   d message
# 0  1   2   3   4   hello
# 1  5   6   7   8   world
# 2  9  10  11  12     foo

# %%
pd.read_csv('ex1.csv', header=[0])
# Out:
#    a   b   c   d message
# 0  1   2   3   4   hello
# 1  5   6   7   8   world
# 2  9  10  11  12     foo

# %%
names=['one', 'two', 'three', 'four', 'message']
pd.read_csv('ex1.csv', names=names, index_col='message')
# Out:
#         one two three four
# message
# message   a   b     c    d
# hello     1   2     3    4
# world     5   6     7    8
# foo       9  10    11   12

# %%
# %%writefile csv_mindex.csv
# key1,key2,value1,value2
# one,a,1,2
# one,b,3,4
# one,c,5,6
# one,d,7,8
# two,a,9,10
# two,b,11,12
# two,c,13,14
# two,d,15,16
# Out:
# Overwriting csv_mindex.csv

# %%
df = pd.read_csv('csv_mindex.csv', index_col=['key1', 'key2'])

# %%
df
# Out:
#            value1  value2
# key1 key2
# one  a          1       2
#      b          3       4
#      c          5       6
#      d          7       8
# two  a          9      10
#      b         11      12
#      c         13      14
#      d         15      16

# %%
# %%writefile ex3
#             A         B         C
# aaa -0.264438 -1.026059 -0.619500
# bbb  0.927272  0.302904 -0.032399
# ccc -0.264273 -0.386314 -0.217601
# ddd -0.871858 -0.348382  1.100491
# Out:
# Overwriting ex3

# %%
pd.read_table('ex3', sep='\s+') # \s+ : 빈칸이 한개도 되고 여러개도 된다는 뜻
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\s'
# <>:1: SyntaxWarning: invalid escape sequence '\s'
# /tmp/ipykernel_7354/4038723380.py:1: SyntaxWarning: invalid escape sequence '\s'
#   pd.read_table('ex3', sep='\s+') # \s+ : 빈칸이 한개도 되고 여러개도 된다는 뜻
#             A         B         C
# aaa -0.264438 -1.026059 -0.619500
# bbb  0.927272  0.302904 -0.032399
# ccc -0.264273 -0.386314 -0.217601
# ddd -0.871858 -0.348382  1.100491

# %%
df.loc[('one', 'a'), :]
# Out:
# value1    1
# value2    2
# Name: (one, a), dtype: int64

# %%
# %%writefile ex4.csv
# # hey!
# a,b,c,d,message
# # just wanted to make things more difficult for you
# # who reads CSV files with computers, anyway?
# 1,2,3,4,hello
# 5,6,7,8,world
# 9,10,11,12,foo
# Out:
# Overwriting ex4.csv

# %%
pd.read_csv('ex4.csv', sep=',', skiprows=[0, 2, 3])
# Out:
#    a   b   c   d message
# 0  1   2   3   4   hello
# 1  5   6   7   8   world
# 2  9  10  11  12     foo

# %%
# %%writefile ex5.csv
# something,a,b,c,d,message
# one,1,2,3,4,NA
# two,5,6,7,8,world
# three,9,10,11,12,foo
# Out:
# Overwriting ex5.csv

# %%
df = pd.read_csv('ex5.csv', nrows=2)

# %%
df
# Out:
#   something  a  b  c  d message
# 0       one  1  2  3  4     NaN
# 1       two  5  6  7  8   world

# %%
df.to_csv('ex6_.csv')

# %%
# !cat ex6_.csv
# Out:
# ,something,a,b,c,d,message
# 0,one,1,2,3,4,
# 1,two,5,6,7,8,world

# %%
df.to_csv('ex7_.csv', sep='|')

# %%
# !cat ex7_.csv
# Out:
# |something|a|b|c|d|message
# 0|one|1|2|3|4|
# 1|two|5|6|7|8|world

# %%
df.to_csv('ex8_.csv', sep='|', na_rep='NA')

# %%
# !cat ex8_.csv
# Out:
# |something|a|b|c|d|message
# 0|one|1|2|3|4|NA
# 1|two|5|6|7|8|world

# %%
df.to_csv('ex9_.csv', index=False)

# %%
# !cat ex9_.csv
# Out:
# something,a,b,c,d,message
# one,1,2,3,4,
# two,5,6,7,8,world

# %%
import sys
df.to_csv(sys.stdout, sep='|')
# Out:
# |something|a|b|c|d|message
# 0|one|1|2|3|4|
# 1|two|5|6|7|8|world

# %%
dates = pd.date_range('1/1/2026', periods = 7)
ts = pd.Series(np.arange(7), index=dates)
ts.to_csv('t_series.csv')

# %%
dates
# Out:
# DatetimeIndex(['2026-01-01', '2026-01-02', '2026-01-03', '2026-01-04',
#                '2026-01-05', '2026-01-06', '2026-01-07'],
#               dtype='datetime64[ns]', freq='D')

# %%
# !cat t_series.csv
# Out:
# ,0
# 2026-01-01,0
# 2026-01-02,1
# 2026-01-03,2
# 2026-01-04,3
# 2026-01-05,4
# 2026-01-06,5
# 2026-01-07,6

# %%
ts
# Out:
# 2026-01-01    0
# 2026-01-02    1
# 2026-01-03    2
# 2026-01-04    3
# 2026-01-05    4
# 2026-01-06    5
# 2026-01-07    6
# Freq: D, dtype: int64

# %%
# %%writefile ex9.csv
# "a","b","c"
# "1","2","3"
# "1","2","3"
# Out:
# Overwriting ex9.csv

# %%
ls
# Out:
# csv_mindex.csv  ex4.csv  ex6_.csv  ex9.csv       t_series.csv
# ex1.csv         ex5.csv  ex7_.csv  ex9_.csv
# ex3             ex6.csv  ex8_.csv  sample_data/

# %%
import csv

# %%
f=open('ex9.csv')
reader = csv.reader(f)

# %%
reader

# %%
for line in reader:
    print(line)
# Out:
# ['a', 'b', 'c']
# ['1', '2', '3']
# ['1', '2', '3']

# %%
f.close()

# %%
with open('ex9.csv') as f:
    lines = list(csv.reader(f))

# %%
lines
# Out:
# [['a', 'b', 'c'], ['1', '2', '3'], ['1', '2', '3']]

# %%
for i in lines:
    print(i)
# Out:
# ['a', 'b', 'c']
# ['1', '2', '3']
# ['1', '2', '3']

# %%
obj = """
{"name": "Wes",
 "places_lived": ["United States", "Spain", "Germany"],
 "pet": null,
 "siblings": [{"name": "Scott", "age": 30, "pets": ["Zeus", "Zuko"]},
              {"name": "Katie", "age": 38,
               "pets": ["Sixes", "Stache", "Cisco"]}]
}
"""

# %%
obj
# Out:
# '\n{"name": "Wes",\n "places_lived": ["United States", "Spain", "Germany"],\n "pet": null,\n "siblings": [{"name": "Scott", "age": 30, "pets": ["Zeus", "Zuko"]},\n              {"name": "Katie", "age": 38,\n               "pets": ["Sixes", "Stache", "Cisco"]}]\n}\n'

# %%
import json
result = json.loads(obj)
result
# Out:
# {'name': 'Wes',
#  'places_lived': ['United States', 'Spain', 'Germany'],
#  'pet': None,
#  'siblings': [{'name': 'Scott', 'age': 30, 'pets': ['Zeus', 'Zuko']},
#   {'name': 'Katie', 'age': 38, 'pets': ['Sixes', 'Stache', 'Cisco']}]}

# %%
result
# Out:
# {'name': 'Wes',
#  'places_lived': ['United States', 'Spain', 'Germany'],
#  'pet': None,
#  'siblings': [{'name': 'Scott', 'age': 30, 'pets': ['Zeus', 'Zuko']},
#   {'name': 'Katie', 'age': 38, 'pets': ['Sixes', 'Stache', 'Cisco']}]}

# %%
type(result)
# Out:
# dict

# %%
asjson = json.dumps(result) # json 형태로
asjson
# Out:
# '{"name": "Wes", "places_lived": ["United States", "Spain", "Germany"], "pet": null, "siblings": [{"name": "Scott", "age": 30, "pets": ["Zeus", "Zuko"]}, {"name": "Katie", "age": 38, "pets": ["Sixes", "Stache", "Cisco"]}]}'

# %%
type(asjson)
# Out:
# str

# %%
print(json.dumps({'4':5, '6':7, '8':9}, sort_keys=True, indent=4)) # indent가 뭘까
# Out:
# {
#     "4": 5,
#     "6": 7,
#     "8": 9
# }
